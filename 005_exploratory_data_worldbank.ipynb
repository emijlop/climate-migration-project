# %%
import pandas as pd

# %%
worldbank_data_somalia = pd.read_csv('data/API_SOM_DS2_en_csv_v2_3285.csv', skiprows=4)

# %%
worldbank_data_somalia.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
worldbank_data_somalia = worldbank_data_somalia[['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '2020', '2021', '2022',
       '2023']]

# %%
worldbank_data_somalia.dropna(subset=['2020', '2021', '2022', '2023'], how='all', inplace=True)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_22192\1971628033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   worldbank_data_somalia.dropna(subset=['2020', '2021', '2022', '2023'], how='all', inplace=True)

# %%
worldbank_data_somalia
# Out:
#      Country Name Country Code  \
# 0         Somalia          SOM
# 1         Somalia          SOM
# 2         Somalia          SOM
# 4         Somalia          SOM
# 5         Somalia          SOM
# ...           ...          ...
# 1487      Somalia          SOM
# 1488      Somalia          SOM
# 1489      Somalia          SOM
# 1492      Somalia          SOM
# 1495      Somalia          SOM
#
#                                          Indicator Name     Indicator Code  \
# 0     Internally displaced persons, total displaced ...        VC.IDP.TOCV
# 1              Voice and Accountability: Standard Error         VA.STD.ERR
# 2           Voice and Accountability: Number of Sources          VA.NO.SRC
# 4                       Export value index (2015 = 100)  TX.VAL.MRCH.XD.WD
# 5     Merchandise exports to low- and middle-income ...  TX.VAL.MRCH.R6.ZS
# ...                                                 ...                ...
# ...
