# %%
import pandas as pd
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
data = pd.read_csv('data/climate_migration_news.csv')

# %%
data_tone = pd.read_csv('data/climate_migration_timelinetone.csv')

# %%
#format date column
data['Date'] = pd.to_datetime(data['Date'])

# %%
data_somalia = data[data['Country'] == 'Somalia']

# %%
data_somalia
# Out:
#      Country  Keyword                                              Title  \
# 771  Somalia  drought  FAO inks $43 . 8 million to reduce flood risk ...
# 772  Somalia  drought  Devastating Floods Submerge 85 % of Beledweyne...
# 773  Somalia  drought  This Year , Malawi Staple Food , Maize , Could...
# 774  Somalia  drought  Garissa Water Future : World Bank supports For...
# 775  Somalia  drought  Somali National Disaster Agency distributes re...
# ..       ...      ...                                                ...
# 851  Somalia  drought  Somaliland : Ports , protests and power projec...
# 852  Somalia  drought  What Somalis are Taking Refuge from – Qaranimo...
# 853  Somalia  drought  Hunger , terrorism and the threat of war : Som...
# 854  Somalia  drought  AISHA AHMED HUSSEIN : ENHANCING ACCESS TO HIGH...
# 855  Somalia  drought    Which way out for Ethiopia - Somalia impasse ?
#
#                                                    URL Source Country  \
# 771  https://www.radiodalsan.com/fao-inks-43-8-mill...        Somalia
# 772  https://jowhar.com/devastating-floods-submerge...        Somalia
# 773  https://jowhar.com/this-year-malawis-staple-fo...        Somalia
# 774  https://www.radiodalsan.com/garissas-water-fut...        Somalia
# 775  https://www.radiodalsan.com/somali-national-di...        Somalia
# ..                                                 ...            ...
# 851  https://somalilandsun.com/ports-protests-and-p...        Somalia
# 852  https://www.qaranimo.com/2016/01/27/what-somal...        Somalia
# 853  https://warsheekh.com/hunger-terrorism-and-the...        Somalia
# 854  https://wardheernews.com/aisha-ahmed-hussein-e...        Somalia
# 855  https://wardheernews.com/which-way-out-for-eth...        Somalia
#
#                          Date
# 771 2023-12-09 08:45:00+00:00
# 772 2023-12-08 16:15:00+00:00
# 773 2024-01-29 15:15:00+00:00
# 774 2024-01-18 00:30:00+00:00
# 775 2024-01-04 04:45:00+00:00
# ..                        ...
# 851 2024-01-18 13:30:00+00:00
# 852 2024-02-04 19:45:00+00:00
# 853 2024-02-28 18:15:00+00:00
# 854 2024-01-27 15:15:00+00:00
# 855 2024-01-28 05:15:00+00:00
#
# [85 rows x 6 columns]

# %%
data_tone.histogram(data_somalia['Date'], data_somalia['Tone'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31880\1727774367.py in ?()
# ----> 1 data_tone.histogram(data_somalia['Date'], data_somalia['Tone'])
#
# c:\Users\LENOVO\anaconda3\envs\hertie_climate_migration\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'histogram'

# %%
somalia_mobility = pd.read_excel('data/somalia_mobility_iom_2024.xlsx')

# %%
somalia_mobility.columns
# Out:
# Index(['Date of Assessment', 'Region Name', 'Region Pcode', 'District Name',
#        'District Pcode', 'OCHA Region Pcode', 'OCHA District Pcode',
#        'Operational Zone', 'Catchment', 'Settlement Name', 'Settlement ID',
#        'Location Type', 'Settlement Classification', 'Neighborhood',
#        'Main Cause of Displacement',
#        'Main Cause of Displacement (type of conflict)',
#        'Main Cause of Displacement (type of Natural hazard)',
#        'New arrivals since last week',
#        'New Arrivals since April 2024 (i.e., since the start of the floods)',
#        'Total new arrivals since last week',
#        'Number of Males (18 and above) since last week',
#        'Number of Females (18 and above) since last week',
#        'Number of Children under 18 since last week',
#        'Departures since last week',
#        'Total number of departures since last week',
#        'What is the reason for majority of the departees to leave this settlement?',
#        'What is the destination of the majority of the departees?',
#        'Region of destination for majority of departees',
#        'District of destination for majority of departees',
#        'Reason for the new arrivals to come to this location',
#        'Final destination of the new arrivals',
#        'If yes, how long does the majority intend to stay',
#        'Date when the new arrivals left their community of origin',
#        'Type of movement of the majority of the new arrivals',
#        'How many times was the majority displaced since they left place of origin',
#        'How long did the whole journey take for the majority',
#        'Origin of the new arrivals (Somalia, Ethiopia or other country)',
#        'Origin of the new arrivals (other country)',
#        'If Ethiopian origin, please specify the Region name',
#        'Somalia Region of Origin', 'Somalia District of Origin',
#        'Somalia Location of Origin',
#        'Main need for the majority of IDPs in settlement',
#        'Response to New Arrivals - No response provided',
#        'Response - General food distribution to new arrivals',
#        'Response - Shelter Materials', 'Response - NFIs',
#        'Response - Health Services', 'Response - Nutrition Services',
#        'Response - Water Services',
#        'Response - Sanitation Services (latrines etc)',
#        'Response - Hygiene Services (soap, hygiene kits, etc)',
#        'Response - General Protection Services', 'Response - GBV Services',
#        'Response - Child Protection Services',
#        'Response - Temporary Learning Classes',
#        'Response - CCCM Site Improvement',
#        'Response - CCCM Complaints and Feedback Mechanism',
#        'Response - CCCM Site Decongestion', 'Response - CCCM Plot Allocation',
#        'Needs to New arrivals - No Immediate needs',
#        'Needs - General Food Distribution', 'Needs - Shelter Materials',
#        'Needs - NFIs', 'Needs - Health Services', 'Needs - Nutrition Services',
#        'Needs - Water Services', 'Needs - Sanitation Services (latrines etc)',
#        'Needs - Hygiene services (soap, hygiene kits, etc)',
#        'Needs - General Protection Services', 'Needs - GBV Services',
#        'Needs - Child Protection Services',
#        'Needs - Temporary Learning Classes', 'Needs - CCCM Site improvement',
#        'Needs - CCCM Complaints and Feedback Mechanism',
#        'Needs - CCCM Site Decongestion', 'Needs - CCCM Plot Allocation',
#        'Round', 'Data Collection Week', 'Origin_Destination',
#        'Origin_Region_country', 'Origin_District_country',
#        'Reason of Displacement'],
#       dtype='object')

# %%
europe_mobility = pd.read_excel('data/DTM_Mixed Migration Flows to Europe_Q3_2024.xlsx',
                                sheet_name='All_Daily Breakdown')

# %%
europe_mobility
# Out:
#      Report Date  Year  Month ISO3 Country or Area Name Country Type  \
# 0     2024-01-31  2024      1  ALB              Albania        Other
# 1     2024-02-29  2024      2  ALB              Albania        Other
# 2     2024-03-31  2024      3  ALB              Albania        Other
# 3     2024-04-30  2024      4  ALB              Albania        Other
# 4     2024-05-31  2024      5  ALB              Albania        Other
# ...          ...   ...    ...  ...                  ...          ...
# 1083  2024-05-31  2024      5  XKX             Kosovo*         Other
# 1084  2024-06-30  2024      6  XKX             Kosovo*         Other
# 1085  2024-07-31  2024      7  XKX             Kosovo*         Other
# 1086  2024-08-31  2024      8  XKX             Kosovo*         Other
# 1087  2024-09-30  2024      9  XKX             Kosovo*         Other
#
#       Daily Arrivals Land  Daily Arrivals Sea  Daily Arrivals Total  \
# 0                      56                   0                    56
# 1                      59                   0                    59
# 2                     142                   0                   142
# 3                     169                   0                   169
# 4                     158                   0                   158
# ...                   ...                 ...                   ...
# 1083                   57                   0                    57
# 1084                   55                   0                    55
# 1085                   85                   0                    85
# 1086                  114                   0                   114
# 1087                   81                   0                    81
#
#       Cumulative Land  Cumulative Sea  Cumulative Total
# 0                  56               0                56
# 1                 115               0               115
# 2                 257               0               257
# 3                 426               0               426
# 4                 584               0               584
# ...               ...             ...               ...
# 1083              353               0               353
# 1084              408               0               408
# 1085              493               0               493
# 1086              607               0               607
# 1087              688               0               688
#
# [1088 rows x 12 columns]

# %%
somalia_mobility
# Out:
#       Date of Assessment     Region Name Region Pcode District Name  \
# 0             2024-05-06         Banadir         SO22         Hodan
# 1             2024-05-08         Banadir         SO22         Hodan
# 2             2024-05-07         Banadir         SO22         Kahda
# 3             2024-05-08  Lower Shabelle         SO23       Afgooye
# 4             2024-08-12             Bay         SO24        Baidoa
# ...                  ...             ...          ...           ...
# 17162         2024-06-01         Banadir         SO22         Kahda
# 17163         2024-06-02          Hiraan         SO20   Belet Weyne
# 17164         2024-06-02         Banadir         SO22         Hodan
# 17165         2024-06-02         Banadir         SO22         Hodan
# 17166         2024-06-02             Bay         SO24        Baidoa
#
#       District Pcode OCHA Region Pcode OCHA District Pcode Operational Zone  \
# 0             SO2208              SO22              SO2201          OPZ 147
# 1             SO2208              SO22              SO2201          OPZ 147
# 2             SO2210              SO22              SO2201          OPZ 148
# 3             SO2302              SO23              SO2302          OPZ 294
# 4             SO2401              SO24              SO2401          OPZ 179
# ...              ...               ...                 ...              ...
# 17162         SO2210              SO22              SO2201          OPZ 148
# 17163         SO2001              SO20              SO2001          OPZ 252
# 17164         SO2208              SO22              SO2201          OPZ 147
# 17165         SO2208              SO22              SO2201          OPZ 147
# 17166         SO2401              SO24              SO2401          OPZ 179
#
#       Catchment                  Settlement Name  ...  \
# 0           NaN                         Uurtaalo  ...
# 1           NaN  Wardheere / Wardheer / Wardhere  ...
# 2          CA14                         Bakeylow  ...
# 3           NaN                           Duurow  ...
# 4          CA03                       Gobor Hose  ...
# ...         ...                              ...  ...
# 17162      CA03                    Buulo Adbiyow  ...
# 17163       NaN                            Gumar  ...
# 17164       NaN                         Malayley  ...
# 17165       NaN                       Dugaal Two  ...
# 17166      CA14                         Banreera  ...
#
#       Needs - CCCM Site improvement  \
# 0                                No
# 1                                No
# 2                                No
# 3                                No
# 4                                No
# ...                             ...
# 17162                           Yes
# 17163                            No
# 17164                            No
# 17165                            No
# 17166                            No
#
#       Needs - CCCM Complaints and Feedback Mechanism  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
# ...                                              ...
# 17162                                             No
# 17163                                             No
# 17164                                             No
# 17165                                             No
# 17166                                             No
#
#       Needs - CCCM Site Decongestion Needs - CCCM Plot Allocation Round  \
# 0                                 No                           No   R06
# 1                                 No                           No   R06
# 2                                 No                           No   R06
# 3                                 No                           No   R06
# 4                                 No                           No   R20
# ...                              ...                          ...   ...
# 17162                             No                           No   R10
# 17163                             No                           No   R10
# 17164                             No                           No   R10
# 17165                             No                           No   R10
# 17166                             No                           No   R10
#
#                  Data Collection Week Origin_Destination  \
# 0          Week 6 (04 - 08 May, 2024)                 OR
# 1          Week 6 (04 - 08 May, 2024)                 OR
# 2          Week 6 (04 - 08 May, 2024)                 OR
# 3          Week 6 (04 - 08 May, 2024)               SRSD
# 4      Week 20 (10 - 14 August, 2024)                 OR
# ...                               ...                ...
# 17162       Week 10 (1 - 5 Jun, 2024)                 OR
# 17163       Week 10 (1 - 5 Jun, 2024)               SRSD
# 17164       Week 10 (1 - 5 Jun, 2024)                 OR
# 17165       Week 10 (1 - 5 Jun, 2024)                 OR
# 17166       Week 10 (1 - 5 Jun, 2024)               SROD
#
#       Origin_Region_country  Origin_District_country  Reason of Displacement
# 0            Lower Shabelle               Wanla Weyn                   Flood
# 1                       Bay                   Baidoa                   Flood
# 2            Lower Shabelle                  Afgooye                   Flood
# 3            Lower Shabelle                  Afgooye                Conflict
# 4                      Gedo                     Luuq                 Drought
# ...                     ...                      ...                     ...
# 17162        Lower Shabelle                  Afgooye                   Flood
# 17163                Hiraan              Belet Weyne                   Flood
# 17164        Lower Shabelle                Qoryooley                   Flood
# 17165       Middle Shabelle                   Jowhar                   Flood
# 17166                   Bay                 Diinsoor                 Drought
#
# [17167 rows x 83 columns]
